# %%
s_achievement = {"math":90,"chinese":100,"english":80}

# %%
def count_total_achievement(achievement):
    return sum(achievement.values())

# %%
count_total_achievement(s_achievement)
